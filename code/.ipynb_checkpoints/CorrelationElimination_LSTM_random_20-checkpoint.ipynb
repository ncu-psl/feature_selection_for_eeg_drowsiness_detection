# %%
import os
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

import torchmetrics
from torchmetrics.functional import accuracy

import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Model Setup

# %%
pl.seed_everything(42, workers=True)

class DrowsyDataset(Dataset):
    
    def __init__(self, sequences):
        self.sequences = sequences
        
    def __len__(self):
        return len(self.sequences)
    
    def __getitem__(self, idx):
        sequence, label = self.sequences[idx]
        return dict(
            sequence=torch.Tensor(sequence.to_numpy()),
            label=torch.tensor(label).long()
        )
    
class DrowsyDataModule(pl.LightningDataModule):
    
    def __init__(self, train_sequences, val_sequences, test_sequences, batch_size):
        super().__init__()
        self.train_sequences = train_sequences
        self.val_sequences = val_sequences
        self.test_sequences = test_sequences
        self.batch_size = batch_size

    def setup(self, stage=None):
        self.train_dataset = DrowsyDataset(self.train_sequences)
        self.val_dataset = DrowsyDataset(self.val_sequences)
        self.test_dataset = DrowsyDataset(self.test_sequences)
        
    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True,
            num_workers=os.cpu_count()
        )
    
    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=os.cpu_count()
        )
    
    def test_dataloader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=os.cpu_count()
        ) 

class DrowsyModel(nn.Module):
    
    def __init__(self, n_features, n_classes, n_hidden=256, n_layers=3):
        super().__init__()
        
        self.n_hidden = n_hidden
        
        self.lstm = nn.LSTM(
            input_size=n_features,
            hidden_size=n_hidden,
            num_layers=n_layers,
            batch_first=True,
            dropout=0.75
        )
        
        self.classifier = nn.Linear(n_hidden, n_classes)
        
    def forward(self, x):
        self.lstm.flatten_parameters()
        _, (hidden, _) = self.lstm(x)
        
        out = hidden[-1]
        return self.classifier(out)
    
class DrowsyPredictor(pl.LightningModule):
    
    def __init__(self, n_features: int, n_classes: int):
        super().__init__()
        self.model = DrowsyModel(n_features, n_classes)
        self.criterion = nn.CrossEntropyLoss()
        
    def forward(self, x, label=None):
        output = self.model(x)
        loss = 0
        if label is not None:
            loss = self.criterion(output, label)
        return loss, output
        
    def training_step(self, batch, batch_idx):
        sequences = batch["sequence"]
        labels = batch["label"]
        loss, outputs = self(sequences, labels)
        predictions = torch.argmax(outputs, dim=1)
        step_accuracy = accuracy(predictions, labels)
        
        self.log("train_loss", loss, prog_bar=True, logger=True)
        self.log("train_accuracy", step_accuracy, prog_bar=True, logger=True)
        
        return {"loss": loss, "accuracy": step_accuracy}
    
    def validation_step(self, batch, batch_idx):
        sequences = batch["sequence"]
        labels = batch["label"]
        loss, outputs = self(sequences, labels)
        predictions = torch.argmax(outputs, dim=1)
        step_accuracy = accuracy(predictions, labels)
        
        self.log("val_loss", loss, prog_bar=True, logger=True)
        self.log("val_accuracy", step_accuracy, prog_bar=True, logger=True)
        
        return {"loss": loss, "accuracy": step_accuracy}
    
    def test_step(self, batch, batch_idx):
        sequences = batch["sequence"]
        labels = batch["label"]
        loss, outputs = self(sequences, labels)
        predictions = torch.argmax(outputs, dim=1)
        step_accuracy = accuracy(predictions, labels)
        
        self.log("test_loss", loss, prog_bar=True, logger=True)
        self.log("test_accuracy", step_accuracy, prog_bar=True, logger=True)
        
        return {"loss": loss, "accuracy": step_accuracy}
    
    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=0.0001)
# Out:
# Global seed set to 42

# %% [markdown]
# ## 參數設置

# %%
# %load_ext tensorboard
# %reload_ext tensorboard
# %tensorboard --logdir ./lightning_logs --host 0.0.0.0 --port=8888
# Out:
# Reusing TensorBoard on port 8888 (pid 4660), started 2 days, 21:21:14 ago. (Use '!kill 4660' to kill it.)
#       <iframe id="tensorboard-frame-1c80317fa3b1799d" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1c80317fa3b1799d");
#           const url = new URL("/", window.location);
#           const port = 8888;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
X_train = pd.read_csv('../data2.csv')

# %%
N_EPOCHS = 200
BATCH_SIZE = 50

# randomed 
ORG_FEATURE_COLUMNS = ['FZ', 'CZ', 'O2', 'T4', 'FT7', 'CPZ', 'F8', 'TP8', 'VEOU', 'P4', 'VEOL', 'C4', 'PO1', 'TP7', 'C3', 'FT10', 'O1', 'T6', 'T3', 'OZ', 'FP1', 'P3', 'F7', 'FT8', 'A2', 'FP2', 'FT9', 'HEOL', 'T5', 'FC4', 'FC3', 'HEOR', 'PZ', 'PO2', 'F4', 'F3', 'CP4', 'CP3', 'FCZ', 'A1']
g = X_train.groupby("group")

# %%
# import random
# ORG_FEATURE_COLUMNS = ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4', 'PO2']
# random.shuffle(ORG_FEATURE_COLUMNS)
# print(ORG_FEATURE_COLUMNS)

# %% [markdown]
# ## Main

# %%
n = 20
FEATURE_COLUMNS = ORG_FEATURE_COLUMNS[n:]

while(n < 21):
    print("------------------ Round: " + str(n) + " ------------------")
    print(FEATURE_COLUMNS)
    print("Len:", len(FEATURE_COLUMNS))
    
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(X_train.state)

    label_encoder.classes_

    X_train['label'] = encoded_labels

    # Prepare data ###########################################
    sequences = [] 

    for name, group in g:
        sequence_features = group[FEATURE_COLUMNS]
        label = group.label.iloc[0]

        # print((sequence_features, label))
        sequences.append((sequence_features, label))

    # Setting up train, test, val gruop #######################
    train_sequences, test_sequences = train_test_split(sequences, test_size=0.2)
    val_sequences, test_sequences = train_test_split(test_sequences, test_size=0.5)


    # Setting up data module ##################################
    data_module = DrowsyDataModule(
        train_sequences, val_sequences, test_sequences, BATCH_SIZE
    )

    model = DrowsyPredictor(
        n_features=len(FEATURE_COLUMNS), 
        n_classes=len(label_encoder.classes_)
    )

    # Check points and logger #################################
    checkpoint_callback = ModelCheckpoint(
        dirpath="checkpoints",
        filename="best-checkpoint-corr-random-" + str(n),
        save_top_k=2,
        verbose=True,
        monitor="val_loss",
        mode="min"
    )

    logger = TensorBoardLogger("lightning_logs", name="Drowsy_Random" + str(n))

    trainer = pl.Trainer(
        logger=logger,
        callbacks=[checkpoint_callback],
        max_epochs=N_EPOCHS,
        gpus=[2],
        # gpus=2, 
        # auto_select_gpus=True,
        auto_lr_find=True, 
        # check_val_every_n_epoch=10
        # refresh_rate=20,
    )
    
    # Training start
    if (n == 20):
        trainer.fit(model, data_module, ckpt_path="/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v6.ckpt")
    else:
        trainer.fit(model, data_module)
    trainer.test(model, data_module)
    
    FEATURE_COLUMNS.pop(0)
    n = n + 1
# Out:
# ------------------ Round: 20 ------------------
# ['FP1', 'P3', 'F7', 'FT8', 'A2', 'FP2', 'FT9', 'HEOL', 'T5', 'FC4', 'FC3', 'HEOR', 'PZ', 'PO2', 'F4', 'F3', 'CP4', 'CP3', 'FCZ', 'A1']
# Len: 20
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2]
# Missing logger folder: lightning_logs/Drowsy_Random20
#
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | model     | DrowsyModel      | 1.3 M
# 1 | criterion | CrossEntropyLoss | 0
# -----------------------------------------------
# 1.3 M     Trainable params
# 0         Non-trainable params
# 1.3 M     Total params
# 5.351     Total estimated model params size (MB)
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/callbacks/model_checkpoint.py:631: UserWarning: Checkpoint directory /Workspace/code/checkpoints exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Global seed set to 42
# Epoch 0:  89%|████████▊ | 226/255 [02:45<00:21,  1.36it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 0:  89%|████████▉ | 228/255 [02:47<00:19,  1.36it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:   7%|▋         | 2/29 [00:02<00:23,  1.14it/s]
# Epoch 0:  90%|█████████ | 230/255 [02:47<00:18,  1.37it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  14%|█▍        | 4/29 [00:02<00:10,  2.38it/s]
# Epoch 0:  91%|█████████ | 232/255 [02:48<00:16,  1.38it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  21%|██        | 6/29 [00:02<00:06,  3.54it/s]
# Epoch 0:  92%|█████████▏| 234/255 [02:48<00:15,  1.39it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  28%|██▊       | 8/29 [00:03<00:04,  4.26it/s]
# Epoch 0:  93%|█████████▎| 236/255 [02:49<00:13,  1.40it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.73it/s]
# Epoch 0:  93%|█████████▎| 238/255 [02:49<00:12,  1.40it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  41%|████▏     | 12/29 [00:03<00:03,  5.05it/s]
# Epoch 0:  94%|█████████▍| 240/255 [02:49<00:10,  1.41it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.04it/s]
# Epoch 0:  95%|█████████▍| 242/255 [02:50<00:09,  1.42it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.34it/s]
# Epoch 0:  96%|█████████▌| 244/255 [02:50<00:07,  1.43it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.26it/s]
# Epoch 0:  96%|█████████▋| 246/255 [02:51<00:06,  1.44it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.29it/s]
# Epoch 0:  97%|█████████▋| 248/255 [02:51<00:04,  1.45it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  76%|███████▌  | 22/29 [00:05<00:01,  5.39it/s]
# Epoch 0:  98%|█████████▊| 250/255 [02:51<00:03,  1.46it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.19it/s]
# Epoch 0:  99%|█████████▉| 252/255 [02:52<00:02,  1.46it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.30it/s]
# Epoch 0: 100%|█████████▉| 254/255 [02:52<00:00,  1.47it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611]
# Validating:  97%|█████████▋| 28/29 [00:06<00:00,  5.39it/s]
# Epoch 0: 100%|██████████| 255/255 [02:53<00:00,  1.47it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611, val_loss=0.643, val_accuracy=0.644]
# Epoch 0: 100%|██████████| 255/255 [02:53<00:00,  1.47it/s, loss=0.63, v_num=0, train_loss=0.585, train_accuracy=0.611, val_loss=0.643, val_accuracy=0.644]
# Epoch 0, global step 225: val_loss reached 0.64309 (best 0.64309), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v5.ckpt" as top 2
# Epoch 1:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 1:  89%|████████▉ | 228/255 [02:44<00:19,  1.39it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:   7%|▋         | 2/29 [00:02<00:25,  1.07it/s]
# Epoch 1:  90%|█████████ | 230/255 [02:44<00:17,  1.40it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  14%|█▍        | 4/29 [00:02<00:10,  2.29it/s]
# Epoch 1:  91%|█████████ | 232/255 [02:44<00:16,  1.41it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  21%|██        | 6/29 [00:02<00:06,  3.38it/s]
# Epoch 1:  92%|█████████▏| 234/255 [02:45<00:14,  1.42it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.17it/s]
# Epoch 1:  93%|█████████▎| 236/255 [02:45<00:13,  1.42it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.66it/s]
# Epoch 1:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.92it/s]
# Epoch 1:  94%|█████████▍| 240/255 [02:46<00:10,  1.44it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.02it/s]
# Epoch 1:  95%|█████████▍| 242/255 [02:46<00:08,  1.45it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.35it/s]
# Epoch 1:  96%|█████████▌| 244/255 [02:47<00:07,  1.46it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.33it/s]
# Epoch 1:  96%|█████████▋| 246/255 [02:47<00:06,  1.47it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.37it/s]
# Epoch 1:  97%|█████████▋| 248/255 [02:47<00:04,  1.48it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  76%|███████▌  | 22/29 [00:05<00:01,  5.42it/s]
# Epoch 1:  98%|█████████▊| 250/255 [02:48<00:03,  1.49it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.39it/s]
# Epoch 1:  99%|█████████▉| 252/255 [02:48<00:02,  1.49it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.34it/s]
# Epoch 1: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.643, val_accuracy=0.644]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.35it/s]
# Epoch 1: 100%|██████████| 255/255 [02:49<00:00,  1.50it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.586, val_accuracy=0.710]
# Epoch 1: 100%|██████████| 255/255 [02:49<00:00,  1.50it/s, loss=0.582, v_num=0, train_loss=0.543, train_accuracy=0.722, val_loss=0.586, val_accuracy=0.710]
# Epoch 1, global step 451: val_loss reached 0.58631 (best 0.58631), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v6.ckpt" as top 2
# Epoch 2:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 2:  89%|████████▉ | 228/255 [02:44<00:19,  1.39it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.01it/s]
# Epoch 2:  90%|█████████ | 230/255 [02:44<00:17,  1.40it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.23it/s]
# Epoch 2:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.44it/s]
# Epoch 2:  92%|█████████▏| 234/255 [02:45<00:14,  1.41it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  28%|██▊       | 8/29 [00:03<00:04,  4.29it/s]
# Epoch 2:  93%|█████████▎| 236/255 [02:45<00:13,  1.42it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.84it/s]
# Epoch 2:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.03it/s]
# Epoch 2:  94%|█████████▍| 240/255 [02:46<00:10,  1.44it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.19it/s]
# Epoch 2:  95%|█████████▍| 242/255 [02:47<00:08,  1.45it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.37it/s]
# Epoch 2:  96%|█████████▌| 244/255 [02:47<00:07,  1.46it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.41it/s]
# Epoch 2:  96%|█████████▋| 246/255 [02:47<00:06,  1.47it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.39it/s]
# Epoch 2:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.30it/s]
# Epoch 2:  98%|█████████▊| 250/255 [02:48<00:03,  1.48it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.22it/s]
# Epoch 2:  99%|█████████▉| 252/255 [02:48<00:02,  1.49it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.27it/s]
# Epoch 2: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.586, val_accuracy=0.710]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.34it/s]
# Epoch 2: 100%|██████████| 255/255 [02:49<00:00,  1.50it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.571, val_accuracy=0.721]
# Epoch 2: 100%|██████████| 255/255 [02:49<00:00,  1.50it/s, loss=0.522, v_num=0, train_loss=0.509, train_accuracy=0.778, val_loss=0.571, val_accuracy=0.721]
# Epoch 2, global step 677: val_loss reached 0.57119 (best 0.57119), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v5.ckpt" as top 2
# Epoch 3:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 3:  89%|████████▉ | 228/255 [02:44<00:19,  1.38it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.01it/s]
# Epoch 3:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.16it/s]
# Epoch 3:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.33it/s]
# Epoch 3:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.17it/s]
# Epoch 3:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.79it/s]
# Epoch 3:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.99it/s]
# Epoch 3:  94%|█████████▍| 240/255 [02:47<00:10,  1.44it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.16it/s]
# Epoch 3:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.36it/s]
# Epoch 3:  96%|█████████▌| 244/255 [02:47<00:07,  1.45it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.29it/s]
# Epoch 3:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.48it/s]
# Epoch 3:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.59it/s]
# Epoch 3:  98%|█████████▊| 250/255 [02:48<00:03,  1.48it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.59it/s]
# Epoch 3:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.61it/s]
# Epoch 3: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.571, val_accuracy=0.721]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.58it/s]
# Epoch 3: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Epoch 3: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.64, v_num=0, train_loss=0.714, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Epoch 3, global step 903: val_loss was not in top 2
# Epoch 4:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 4:  89%|████████▉ | 228/255 [02:44<00:19,  1.38it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:   7%|▋         | 2/29 [00:02<00:27,  1.00s/it]
# Epoch 4:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.22it/s]
# Epoch 4:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.41it/s]
# Epoch 4:  92%|█████████▏| 234/255 [02:45<00:14,  1.41it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  28%|██▊       | 8/29 [00:03<00:04,  4.35it/s]
# Epoch 4:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.89it/s]
# Epoch 4:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.19it/s]
# Epoch 4:  94%|█████████▍| 240/255 [02:47<00:10,  1.44it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.20it/s]
# Epoch 4:  95%|█████████▍| 242/255 [02:47<00:08,  1.45it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.36it/s]
# Epoch 4:  96%|█████████▌| 244/255 [02:47<00:07,  1.45it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.36it/s]
# Epoch 4:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.26it/s]
# Epoch 4:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.29it/s]
# Epoch 4:  98%|█████████▊| 250/255 [02:48<00:03,  1.48it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.27it/s]
# Epoch 4:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.18it/s]
# Epoch 4: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.642, val_accuracy=0.646]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.31it/s]
# Epoch 4: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.600, val_accuracy=0.652]
# Epoch 4: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.616, v_num=0, train_loss=0.595, train_accuracy=0.611, val_loss=0.600, val_accuracy=0.652]
# Epoch 4, global step 1129: val_loss was not in top 2
# Epoch 5:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 5:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.03it/s]
# Epoch 5:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.26it/s]
# Epoch 5:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.34it/s]
# Epoch 5:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.20it/s]
# Epoch 5:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.84it/s]
# Epoch 5:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.92it/s]
# Epoch 5:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.11it/s]
# Epoch 5:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.27it/s]
# Epoch 5:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.30it/s]
# Epoch 5:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.39it/s]
# Epoch 5:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.24it/s]
# Epoch 5:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.44it/s]
# Epoch 5:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.53it/s]
# Epoch 5: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.600, val_accuracy=0.652]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.55it/s]
# Epoch 5: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.634, val_accuracy=0.640]
# Epoch 5: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.637, v_num=0, train_loss=0.528, train_accuracy=0.778, val_loss=0.634, val_accuracy=0.640]
# Epoch 5, global step 1355: val_loss was not in top 2
# Epoch 6:  89%|████████▊ | 226/255 [02:43<00:20,  1.38it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 6:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.01it/s]
# Epoch 6:  90%|█████████ | 230/255 [02:45<00:18,  1.39it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.22it/s]
# Epoch 6:  91%|█████████ | 232/255 [02:46<00:16,  1.39it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.29it/s]
# Epoch 6:  92%|█████████▏| 234/255 [02:46<00:14,  1.40it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  28%|██▊       | 8/29 [00:03<00:04,  4.20it/s]
# Epoch 6:  93%|█████████▎| 236/255 [02:47<00:13,  1.41it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.76it/s]
# Epoch 6:  93%|█████████▎| 238/255 [02:47<00:11,  1.42it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.98it/s]
# Epoch 6:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.23it/s]
# Epoch 6:  95%|█████████▍| 242/255 [02:48<00:09,  1.44it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.46it/s]
# Epoch 6:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.34it/s]
# Epoch 6:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.30it/s]
# Epoch 6:  97%|█████████▋| 248/255 [02:49<00:04,  1.46it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.26it/s]
# Epoch 6:  98%|█████████▊| 250/255 [02:49<00:03,  1.47it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.33it/s]
# Epoch 6:  99%|█████████▉| 252/255 [02:50<00:02,  1.48it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.26it/s]
# Epoch 6: 100%|█████████▉| 254/255 [02:50<00:00,  1.49it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.634, val_accuracy=0.640]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.38it/s]
# Epoch 6: 100%|██████████| 255/255 [02:51<00:00,  1.49it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.558, val_accuracy=0.748]
# Epoch 6: 100%|██████████| 255/255 [02:51<00:00,  1.49it/s, loss=0.548, v_num=0, train_loss=0.601, train_accuracy=0.667, val_loss=0.558, val_accuracy=0.748]
# Epoch 6, global step 1581: val_loss reached 0.55806 (best 0.55806), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v6.ckpt" as top 2
# Epoch 7:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 7:  89%|████████▉ | 228/255 [02:44<00:19,  1.38it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.01it/s]
# Epoch 7:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.21it/s]
# Epoch 7:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.34it/s]
# Epoch 7:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.12it/s]
# Epoch 7:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.73it/s]
# Epoch 7:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.15it/s]
# Epoch 7:  94%|█████████▍| 240/255 [02:47<00:10,  1.44it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.17it/s]
# Epoch 7:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.19it/s]
# Epoch 7:  96%|█████████▌| 244/255 [02:47<00:07,  1.45it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.35it/s]
# Epoch 7:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.36it/s]
# Epoch 7:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.36it/s]
# Epoch 7:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.38it/s]
# Epoch 7:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.30it/s]
# Epoch 7: 100%|█████████▉| 254/255 [02:49<00:00,  1.50it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.558, val_accuracy=0.748]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.21it/s]
# Epoch 7: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.551, val_accuracy=0.744]
# Epoch 7: 100%|██████████| 255/255 [02:50<00:00,  1.50it/s, loss=0.444, v_num=0, train_loss=0.404, train_accuracy=0.889, val_loss=0.551, val_accuracy=0.744]
# Epoch 7, global step 1807: val_loss reached 0.55139 (best 0.55139), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v5.ckpt" as top 2
# Epoch 8:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 8:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.02it/s]
# Epoch 8:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.23it/s]
# Epoch 8:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.35it/s]
# Epoch 8:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.10it/s]
# Epoch 8:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.63it/s]
# Epoch 8:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.92it/s]
# Epoch 8:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.05it/s]
# Epoch 8:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.14it/s]
# Epoch 8:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.31it/s]
# Epoch 8:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.23it/s]
# Epoch 8:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.35it/s]
# Epoch 8:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.32it/s]
# Epoch 8:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.27it/s]
# Epoch 8: 100%|█████████▉| 254/255 [02:50<00:00,  1.49it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.551, val_accuracy=0.744]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.33it/s]
# Epoch 8: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Epoch 8: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.507, v_num=0, train_loss=0.422, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Epoch 8, global step 2033: val_loss reached 0.48461 (best 0.48461), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v6.ckpt" as top 2
# Epoch 9:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 9:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.00it/s]
# Epoch 9:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.21it/s]
# Epoch 9:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.38it/s]
# Epoch 9:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.16it/s]
# Epoch 9:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.67it/s]
# Epoch 9:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.07it/s]
# Epoch 9:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.22it/s]
# Epoch 9:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.19it/s]
# Epoch 9:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.30it/s]
# Epoch 9:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.35it/s]
# Epoch 9:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.45it/s]
# Epoch 9:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.35it/s]
# Epoch 9:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.25it/s]
# Epoch 9: 100%|█████████▉| 254/255 [02:49<00:00,  1.49it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.485, val_accuracy=0.785]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.35it/s]
# Epoch 9: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.441, val_accuracy=0.806]
# Epoch 9: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.448, v_num=0, train_loss=0.401, train_accuracy=0.778, val_loss=0.441, val_accuracy=0.806]
# Epoch 9, global step 2259: val_loss reached 0.44083 (best 0.44083), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v5.ckpt" as top 2
# Epoch 10:  89%|████████▊ | 226/255 [02:43<00:20,  1.39it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 10:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.02it/s]
# Epoch 10:  90%|█████████ | 230/255 [02:45<00:18,  1.39it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.20it/s]
# Epoch 10:  91%|█████████ | 232/255 [02:46<00:16,  1.40it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.31it/s]
# Epoch 10:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.11it/s]
# Epoch 10:  93%|█████████▎| 236/255 [02:46<00:13,  1.41it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.71it/s]
# Epoch 10:  93%|█████████▎| 238/255 [02:47<00:11,  1.42it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  4.98it/s]
# Epoch 10:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.19it/s]
# Epoch 10:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.20it/s]
# Epoch 10:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.30it/s]
# Epoch 10:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.37it/s]
# Epoch 10:  97%|█████████▋| 248/255 [02:49<00:04,  1.47it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.44it/s]
# Epoch 10:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.45it/s]
# Epoch 10:  99%|█████████▉| 252/255 [02:49<00:02,  1.48it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.36it/s]
# Epoch 10: 100%|█████████▉| 254/255 [02:50<00:00,  1.49it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.441, val_accuracy=0.806]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.30it/s]
# Epoch 10: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.554, val_accuracy=0.766]
# Epoch 10: 100%|██████████| 255/255 [02:50<00:00,  1.49it/s, loss=0.482, v_num=0, train_loss=0.397, train_accuracy=0.833, val_loss=0.554, val_accuracy=0.766]
# Epoch 10, global step 2485: val_loss was not in top 2
# Epoch 11:  89%|████████▊ | 226/255 [02:41<00:20,  1.40it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 11:  89%|████████▉ | 228/255 [02:43<00:19,  1.39it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.02it/s]
# Epoch 11:  90%|█████████ | 230/255 [02:44<00:17,  1.40it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.18it/s]
# Epoch 11:  91%|█████████ | 232/255 [02:44<00:16,  1.41it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.32it/s]
# Epoch 11:  92%|█████████▏| 234/255 [02:44<00:14,  1.42it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  28%|██▊       | 8/29 [00:03<00:04,  4.22it/s]
# Epoch 11:  93%|█████████▎| 236/255 [02:45<00:13,  1.43it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  34%|███▍      | 10/29 [00:03<00:03,  4.81it/s]
# Epoch 11:  93%|█████████▎| 238/255 [02:45<00:11,  1.44it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.09it/s]
# Epoch 11:  94%|█████████▍| 240/255 [02:45<00:10,  1.45it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.28it/s]
# Epoch 11:  95%|█████████▍| 242/255 [02:46<00:08,  1.46it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.39it/s]
# Epoch 11:  96%|█████████▌| 244/255 [02:46<00:07,  1.46it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.29it/s]
# Epoch 11:  96%|█████████▋| 246/255 [02:47<00:06,  1.47it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.25it/s]
# Epoch 11:  97%|█████████▋| 248/255 [02:47<00:04,  1.48it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.35it/s]
# Epoch 11:  98%|█████████▊| 250/255 [02:47<00:03,  1.49it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.35it/s]
# Epoch 11:  99%|█████████▉| 252/255 [02:48<00:02,  1.50it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.34it/s]
# Epoch 11: 100%|█████████▉| 254/255 [02:48<00:00,  1.51it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.554, val_accuracy=0.766]
# Validating:  97%|█████████▋| 28/29 [00:07<00:00,  5.40it/s]
# Epoch 11: 100%|██████████| 255/255 [02:49<00:00,  1.51it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.465, val_accuracy=0.757]
# Epoch 11: 100%|██████████| 255/255 [02:49<00:00,  1.51it/s, loss=0.445, v_num=0, train_loss=0.541, train_accuracy=0.722, val_loss=0.465, val_accuracy=0.757]
# Epoch 11, global step 2711: val_loss reached 0.46490 (best 0.44083), saving model to "/Workspace/code/checkpoints/best-checkpoint-corr-random-20-v6.ckpt" as top 2
# Epoch 12:  89%|████████▊ | 226/255 [02:42<00:20,  1.39it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating: 0it [00:00, ?it/s]
# Validating:   0%|          | 0/29 [00:00<?, ?it/s]
# Epoch 12:  89%|████████▉ | 228/255 [02:45<00:19,  1.38it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:   7%|▋         | 2/29 [00:02<00:26,  1.01it/s]
# Epoch 12:  90%|█████████ | 230/255 [02:45<00:17,  1.39it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  14%|█▍        | 4/29 [00:02<00:11,  2.20it/s]
# Epoch 12:  91%|█████████ | 232/255 [02:45<00:16,  1.40it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  21%|██        | 6/29 [00:03<00:06,  3.32it/s]
# Epoch 12:  92%|█████████▏| 234/255 [02:46<00:14,  1.41it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  28%|██▊       | 8/29 [00:03<00:05,  4.14it/s]
# Epoch 12:  93%|█████████▎| 236/255 [02:46<00:13,  1.42it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  34%|███▍      | 10/29 [00:03<00:04,  4.74it/s]
# Epoch 12:  93%|█████████▎| 238/255 [02:46<00:11,  1.43it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  41%|████▏     | 12/29 [00:04<00:03,  5.14it/s]
# Epoch 12:  94%|█████████▍| 240/255 [02:47<00:10,  1.43it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  48%|████▊     | 14/29 [00:04<00:02,  5.13it/s]
# Epoch 12:  95%|█████████▍| 242/255 [02:47<00:09,  1.44it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  55%|█████▌    | 16/29 [00:04<00:02,  5.26it/s]
# Epoch 12:  96%|█████████▌| 244/255 [02:48<00:07,  1.45it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  62%|██████▏   | 18/29 [00:05<00:02,  5.31it/s]
# Epoch 12:  96%|█████████▋| 246/255 [02:48<00:06,  1.46it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  69%|██████▉   | 20/29 [00:05<00:01,  5.30it/s]
# Epoch 12:  97%|█████████▋| 248/255 [02:48<00:04,  1.47it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  76%|███████▌  | 22/29 [00:06<00:01,  5.41it/s]
# Epoch 12:  98%|█████████▊| 250/255 [02:49<00:03,  1.48it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  83%|████████▎ | 24/29 [00:06<00:00,  5.50it/s]
# Epoch 12:  99%|█████████▉| 252/255 [02:49<00:02,  1.49it/s, loss=0.443, v_num=0, train_loss=0.324, train_accuracy=0.889, val_loss=0.465, val_accuracy=0.757]
# Validating:  90%|████████▉ | 26/29 [00:06<00:00,  5.36it/s]
# ...
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-16vovpct/listener-j2tdqrt0'
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
# Traceback (most recent call last):
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-q14cc_p2/listener-m8dqpx4i'
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-svpn4vtd'
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-u90vzfi6'
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-x4xoh95a/listener-tpwq5mgv'
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-jrltb6cz'
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 262, in _run_finalizers
#     finalizer()
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-ng5z0kmz'
#   File "/usr/lib/python3.6/multiprocessing/util.py", line 186, in __call__
#     res = self._callback(*self._args, **self._kwargs)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-beaqo5_j'
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-zjs_lg8z'
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 477, in rmtree
#     onerror(os.lstat, path, sys.exc_info())
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-x4xoh95a'
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-8g11327i'
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-16vovpct'
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-q14cc_p2'
#   File "/usr/lib/python3.6/shutil.py", line 475, in rmtree
#     orig_st = os.lstat(path)
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-ypm2o2ri'
# FileNotFoundError: [Errno 2] No such file or directory: '/tmp/pymp-dt8t51n9'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-0ee2287c8265> in <module>
#      67         trainer.fit(model, data_module, ckpt_path="/Workspace/code/checkpoints/best-checkpoint-corr-random-18-v1.ckpt")
#      68     else:
# ---> 69         trainer.fit(model, data_module)
#      70     trainer.test(model, data_module)
#      71
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, train_dataloader, ckpt_path)
#     739             train_dataloaders = train_dataloader
#     740         self._call_and_handle_interrupt(
# --> 741             self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     742         )
#     743
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in _call_and_handle_interrupt(self, trainer_fn, *args, **kwargs)
#     683         """
#     684         try:
# --> 685             return trainer_fn(*args, **kwargs)
#     686         # TODO: treat KeyboardInterrupt as BaseException (delete the code below) in v1.7
#     687         except KeyboardInterrupt as exception:
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     775         # TODO: ckpt_path only in v1.7
#     776         ckpt_path = ckpt_path or self.resume_from_checkpoint
# --> 777         self._run(model, ckpt_path=ckpt_path)
#     778
#     779         assert self.state.stopped
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in _run(self, model, ckpt_path)
#    1197
#    1198         # dispatch `start_training` or `start_evaluating` or `start_predicting`
# -> 1199         self._dispatch()
#    1200
#    1201         # plugin will finalized fitting (e.g. ddp_spawn will load trained model)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in _dispatch(self)
#    1277             self.training_type_plugin.start_predicting(self)
#    1278         else:
# -> 1279             self.training_type_plugin.start_training(self)
#    1280
#    1281     def run_stage(self):
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/plugins/training_type/training_type_plugin.py in start_training(self, trainer)
#     200     def start_training(self, trainer: "pl.Trainer") -> None:
#     201         # double dispatch to initiate the training loop
# --> 202         self._results = trainer.run_stage()
#     203
#     204     def start_evaluating(self, trainer: "pl.Trainer") -> None:
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in run_stage(self)
#    1287         if self.predicting:
#    1288             return self._run_predict()
# -> 1289         return self._run_train()
#    1290
#    1291     def _pre_training_routine(self):
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/trainer.py in _run_train(self)
#    1317         self.fit_loop.trainer = self
#    1318         with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1319             self.fit_loop.run()
#    1320
#    1321     def _run_evaluate(self) -> _EVALUATE_OUTPUT:
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/loops/base.py in run(self, *args, **kwargs)
#     143             try:
#     144                 self.on_advance_start(*args, **kwargs)
# --> 145                 self.advance(*args, **kwargs)
#     146                 self.on_advance_end()
#     147                 self.restarting = False
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/loops/fit_loop.py in advance(self)
#     232
#     233         with self.trainer.profiler.profile("run_training_epoch"):
# --> 234             self.epoch_loop.run(data_fetcher)
#     235
#     236             # the global step is manually decreased here due to backwards compatibility with existing loggers
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/loops/base.py in run(self, *args, **kwargs)
#     143             try:
#     144                 self.on_advance_start(*args, **kwargs)
# --> 145                 self.advance(*args, **kwargs)
#     146                 self.on_advance_end()
#     147                 self.restarting = False
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/loops/epoch/training_epoch_loop.py in advance(self, *args, **kwargs)
#     154             return
#     155
# --> 156         batch_idx, (batch, self.batch_progress.is_last_batch) = next(self._dataloader_iter)
#     157
#     158         if not self.trainer._data_connector.train_data_fetcher.store_on_device:
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/fetching.py in __next__(self)
#     201
#     202     def __next__(self):
# --> 203         return self.fetching_function()
#     204
#     205     def reset(self) -> None:
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/fetching.py in fetching_function(self)
#     268             try:
#     269                 yield_batch = self.pop_batch()
# --> 270                 self._fetch_next_batch()
#     271
#     272                 # wait for batch to be available.
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/fetching.py in _fetch_next_batch(self)
#     298                 data = self.on_fetch_start()
#     299                 with self.apply_profiler(f"fetch_next_{self.stage}_batch"):
# --> 300                     batch = next(self.dataloader_iter)
#     301                 self.fetched += 1
#     302                 self.on_fetch_end(batch, data)
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/supporters.py in __next__(self)
#     548             a collections of batch data
#     549         """
# --> 550         return self.request_next_batch(self.loader_iters)
#     551
#     552     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/trainer/supporters.py in request_next_batch(loader_iters)
#     560             Any: a collections of batch data
#     561         """
# --> 562         return apply_to_collection(loader_iters, Iterator, next)
#     563
#     564     @staticmethod
#
# /usr/local/lib/python3.6/dist-packages/pytorch_lightning/utilities/apply_func.py in apply_to_collection(data, dtype, function, wrong_dtype, include_none, *args, **kwargs)
#      93     # Breaking condition
#      94     if isinstance(data, dtype) and (wrong_dtype is None or not isinstance(data, wrong_dtype)):
# ---> 95         return function(data, *args, **kwargs)
#      96
#      97     elem_type = type(data)
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     519             if self._sampler_iter is None:
#     520                 self._reset()
# --> 521             data = self._next_data()
#     522             self._num_yielded += 1
#     523             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1184
#    1185             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1186             idx, data = self._get_data()
#    1187             self._tasks_outstanding -= 1
#    1188             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1150         else:
#    1151             while True:
# -> 1152                 success, data = self._try_get_data()
#    1153                 if success:
#    1154                     return data
#
# /usr/local/lib/python3.6/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#     988         #   (bool: whether successfully get data, any: data if successful else None)
#     989         try:
# --> 990             data = self._data_queue.get(timeout=timeout)
#     991             return (True, data)
#     992         except Exception as e:
#
# /usr/lib/python3.6/multiprocessing/queues.py in get(self, block, timeout)
#     111                 self._rlock.release()
#     112         # unserialize the data after having released the lock
# --> 113         return _ForkingPickler.loads(res)
#     114
#     115     def qsize(self):
#
# /usr/local/lib/python3.6/dist-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     287
#     288 def rebuild_storage_fd(cls, df, size):
# --> 289     fd = df.detach()
#     290     try:
#     291         storage = storage_from_cache(cls, fd_id(fd))
#
# /usr/lib/python3.6/multiprocessing/resource_sharer.py in detach(self)
#      55         def detach(self):
#      56             '''Get the fd.  This should only be called once.'''
# ---> 57             with _resource_sharer.get_connection(self._id) as conn:
#      58                 return reduction.recv_handle(conn)
#      59
#
# /usr/lib/python3.6/multiprocessing/resource_sharer.py in get_connection(ident)
#      85         from .connection import Client
#      86         address, key = ident
# ---> 87         c = Client(address, authkey=process.current_process().authkey)
#      88         c.send((key, os.getpid()))
#      89         return c
#
# /usr/lib/python3.6/multiprocessing/connection.py in Client(address, family, authkey)
#     485         c = PipeClient(address)
#     486     else:
# --> 487         c = SocketClient(address)
#     488
#     489     if authkey is not None and not isinstance(authkey, bytes):
#
# /usr/lib/python3.6/multiprocessing/connection.py in SocketClient(address)
#     612     with socket.socket( getattr(socket, family) ) as s:
#     613         s.setblocking(True)
# --> 614         s.connect(address)
#     615         return Connection(s.detach())
#     616
#
# FileNotFoundError: [Errno 2] No such file or directory

# %% [markdown]
# ## Load Checkpoint

# %%
# best-checkpoint-corr-3-v1.ckptn
# trainer.fit(model, data_module, ckpt_path="/Workspace/code/checkpoints/best-checkpoint-corr-3-v1.ckpt")
# Out:
# Epoch 87:  84%|████████▍ | 215/255 [02:47<00:31,  1.29it/s, loss=0.204, v_num=0, train_loss=0.0891, train_accuracy=0.980, val_loss=0.229, val_accuracy=0.906]
