# %%
import os
import pandas as pd
import numpy as np
# import dataframe as df
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt

import torch
from torch import nn, optim
from torch.nn import functional as F
from torch.utils.data import Dataset, DataLoader

import torchmetrics
from torchmetrics.functional import accuracy

import pytorch_lightning as pl
from pytorch_lightning.loggers import TensorBoardLogger
from pytorch_lightning.callbacks import ModelCheckpoint

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)

import seaborn as sns
# Out:
# cuda

# %%
X_train = pd.read_csv('../data2.csv')

# %%
X_train.head()
X_train.shape
X_train.info()
print(X_train.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14424064 entries, 0 to 14424063
# Data columns (total 44 columns):
#  #   Column  Dtype
# ---  ------  -----
#  0   time    int64
#  1   id      int64
#  2   group   int64
#  3   state   object
#  4   HEOL    float64
#  5   HEOR    float64
#  6   FP1     float64
#  7   FP2     float64
#  8   VEOU    float64
#  9   VEOL    float64
#  10  F7      float64
#  11  F3      float64
#  12  FZ      float64
#  13  F4      float64
#  14  F8      float64
#  15  FT7     float64
#  16  FC3     float64
#  17  FCZ     float64
#  18  FC4     float64
#  19  FT8     float64
#  20  T3      float64
#  21  C3      float64
#  22  CZ      float64
#  23  C4      float64
#  24  T4      float64
#  25  TP7     float64
#  26  CP3     float64
#  27  CPZ     float64
#  28  CP4     float64
#  29  TP8     float64
#  30  A1      float64
#  31  T5      float64
#  32  P3      float64
#  33  PZ      float64
#  34  P4      float64
#  35  T6      float64
#  36  A2      float64
#  37  O1      float64
#  38  OZ      float64
#  39  O2      float64
#  40  FT9     float64
#  41  FT10    float64
#  42  PO1     float64
#  43  PO2     float64
# dtypes: float64(40), int64(3), object(1)
# memory usage: 4.7+ GB
#                time            id         group          HEOL          HEOR  \
# count  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07
# mean   3.005016e+05  5.115000e+02  7.042500e+03 -2.439227e-01 -4.473785e-06
# std    1.734958e+05  2.956032e+02  4.066278e+03  1.417591e+02  2.057471e-03
# min    0.000000e+00  0.000000e+00  0.000000e+00 -2.423110e+03 -1.457554e-01
# 25%    1.502500e+05  2.557500e+02  3.521000e+03 -6.190002e+00 -4.411773e-06
# 50%    3.005010e+05  5.115000e+02  7.042500e+03 -7.374709e-02  3.805031e-17
# 75%    4.507512e+05  7.672500e+02  1.056400e+04  5.999642e+00  4.411773e-06
# max    6.031350e+05  1.023000e+03  1.408500e+04  2.466700e+03  1.457554e-01
#
#                 FP1           FP2          VEOU          VEOL            F7  \
# count  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07
# mean   5.773373e-02  2.343737e-05  1.248845e-01 -2.103808e-07 -1.129953e-01
# std    8.339794e+01  2.307205e-03  1.077504e+02  2.115590e-03  1.295939e+02
# min   -2.368078e+03 -2.186332e-01 -2.474023e+03 -1.457554e-01 -3.335907e+03
# 25%   -3.428775e+00 -8.823546e-06 -8.853879e+00 -2.205886e-06 -9.158379e+00
# 50%   -1.496850e-02  0.000000e+00 -7.727690e-01  8.065011e-18 -6.560437e-01
# 75%    3.434818e+00  8.823546e-06  7.250152e+00  2.205886e-06  7.814116e+00
# max    2.267657e+03  2.915109e-01  2.503797e+03  1.457554e-01  2.356444e+03
#
#        ...            P4            T6            A2            O1  \
# count  ...  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07
# mean   ...  9.556272e-02  7.337612e-06  5.512840e-02 -1.243758e-05
# std    ...  1.235080e+02  1.941967e-03  9.202586e+01  2.096256e-03
# min    ... -3.588359e+03 -1.093166e-01 -2.221483e+03 -2.186332e-01
# 25%    ... -7.320091e+00 -2.205886e-06 -3.934473e+00 -4.411773e-06
# 50%    ... -1.742739e-01  2.316106e-17 -3.341449e-03  0.000000e+00
# 75%    ...  7.101895e+00  2.205886e-06  3.771538e+00  4.411773e-06
# max    ...  3.307722e+03  2.186332e-01  2.330551e+03  2.186332e-01
#
#                  OZ            O2           FT9          FT10           PO1  \
# count  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07  1.442406e+07
# mean   6.432549e-02 -2.342769e-05 -8.160863e-02 -4.234038e-05  8.383373e-02
# std    4.985286e+01  2.555370e-03  8.100512e+01  2.768569e-03  5.829068e+01
# min   -2.394785e+03 -2.915109e-01 -2.929211e+03 -3.643886e-01 -2.417340e+03
# 25%   -3.581198e+00 -6.617659e-06 -3.813189e+00 -8.823546e-06 -3.441107e+00
# 50%   -1.114007e-01  0.000000e+00 -9.888858e-02 -2.205886e-06 -1.096380e-01
# 75%    3.432722e+00  6.617659e-06  3.670362e+00  8.823546e-06  3.291780e+00
# max    2.323738e+03  1.821943e-01  2.368203e+03  1.821943e-01  2.285776e+03
#
#                 PO2
# count  1.442406e+07
# mean  -2.896002e-05
# std    2.312270e-03
# min   -2.550720e-01
# 25%   -6.617659e-06
# 50%    0.000000e+00
# 75%    6.617659e-06
# max    1.665105e-01
#
# [8 rows x 43 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib qt
# %matplotlib inline

hello = X_train.drop(columns=['time', 'id', 'group', 'state'])
# hello.boxplot()

# %%
# Plot EEG Distrobution

FEATURE_COLUMNS = hello.columns.to_list() 

# plt.figure(1)
# plt.subplots_adjust(hspace=0.5)

# for c in FEATURE_COLUMNS:
#     print(c)
#     plt.hist(hello[c], color='skyblue', edgecolor='orange')
#     plt.xlabel(c)
#     plt.ylabel('Frequency')
#     plt.show()

# %% [markdown]
# ## Correlation Matrix

# %%
corr = hello.corr()

# %% [markdown]
# ## Feature Extraction

# %%
rm_list = []
hello = X_train.drop(columns=['time', 'id', 'group', 'state'])

n = 0
while(FEATURE_COLUMNS):
    print("-----Round:", n, "-----") 
    
    corr = hello.corr()
    corr_list = []
    FEATURE_COLUMNS = corr.columns.tolist()
    print(FEATURE_COLUMNS)
    
    for i in FEATURE_COLUMNS:
        for j in FEATURE_COLUMNS:
            if i == j:
                pass
            elif FEATURE_COLUMNS.index(i) >= FEATURE_COLUMNS.index(j):
                pass
            else:
                corr_list.append([corr[i][j], i, j])

    corr_df = pd.DataFrame(corr_list, columns=['value', 'C1', 'C2'])        
    corr_df = corr_df.reindex(corr_df.value.abs().sort_values().index)
    print(corr_df.info)
    
    if not corr_df.empty:
        print(corr_df.iloc[-1]['C1'] in FEATURE_COLUMNS)
        hello = hello.drop(columns=[corr_df.iloc[-1]['C1']])
        rm_list.append(corr_df.iloc[-1]['C1'])
    print("rm_list:", rm_list)
    
    n = n + 1
    
print("-------end--------")
print("rm_list:", rm_list)
# Out:
# -----Round: 0 -----
# ['HEOL', 'HEOR', 'FP1', 'FP2', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FCZ', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'TP8', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'O2', 'FT9', 'FT10', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 48   0.000017  HEOR   FT7
# 185  0.000090  VEOL    F7
# 19   0.000163  HEOL    T4
# 525 -0.000179    T3   PO1
# 608  0.000217    T4   PO2
# ..        ...   ...   ...
# 135 -0.787296   FP2   TP8
# 452  0.792880   FCZ  FT10
# 147 -0.802031   FP2  FT10
# 123 -0.809594   FP2   FCZ
# 686  0.856041   TP8  FT10
#
# [780 rows x 3 columns]>
# True
# rm_list: ['TP8']
# -----Round: 1 -----
# ['HEOL', 'HEOR', 'FP1', 'FP2', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FCZ', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'O2', 'FT9', 'FT10', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 47   0.000017  HEOR   FT7
# 180  0.000090  VEOL    F7
# 19   0.000163  HEOL    T4
# 508 -0.000179    T3   PO1
# 587  0.000217    T4   PO2
# ..        ...   ...   ...
# 732  0.708371    O2  FT10
# 739  0.785822  FT10   PO2
# 438  0.792880   FCZ  FT10
# 143 -0.802031   FP2  FT10
# 120 -0.809594   FP2   FCZ
#
# [741 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2']
# -----Round: 2 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FCZ', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'O2', 'FT9', 'FT10', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 45   0.000017  HEOR   FT7
# 142  0.000090  VEOL    F7
# 18   0.000163  HEOL    T4
# 470 -0.000179    T3   PO1
# 549  0.000217    T4   PO2
# ..        ...   ...   ...
# 398  0.669617   FCZ    O2
# 696  0.681939    O2   PO2
# 694  0.708371    O2  FT10
# 701  0.785822  FT10   PO2
# 400  0.792880   FCZ  FT10
#
# [703 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ']
# -----Round: 3 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'O2', 'FT9', 'FT10', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 44   0.000017  HEOR   FT7
# 138  0.000090  VEOL    F7
# 17   0.000163  HEOL    T4
# 433 -0.000179    T3   PO1
# 512  0.000217    T4   PO2
# ..        ...   ...   ...
# 646  0.565142    O1    O2
# 648  0.629835    O1  FT10
# 659  0.681939    O2   PO2
# 657  0.708371    O2  FT10
# 664  0.785822  FT10   PO2
#
# [666 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10']
# -----Round: 4 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'O2', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 43   0.000017  HEOR  FT7
# 134  0.000090  VEOL   F7
# 17   0.000163  HEOL   T4
# 418 -0.000179    T3  PO1
# 493  0.000217    T4  PO2
# ..        ...   ...  ...
# 313  0.386831   FT7  TP7
# 329 -0.513946   FT7  PO2
# 619  0.524527    O1  PO2
# 616  0.565142    O1   O2
# 626  0.681939    O2  PO2
#
# [630 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2']
# -----Round: 5 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'O1', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 42   0.000017  HEOR  FT7
# 130  0.000090  VEOL   F7
# 17   0.000163  HEOL   T4
# 403 -0.000179    T3  PO1
# 474  0.000217    T4  PO2
# ..        ...   ...  ...
# 269 -0.371326    F4  PO2
# 265 -0.386442    F4   O1
# 303  0.386831   FT7  TP7
# 318 -0.513946   FT7  PO2
# 588  0.524527    O1  PO2
#
# [595 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1']
# -----Round: 6 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FT7', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 41   0.000017  HEOR  FT7
# 126  0.000090  VEOL   F7
# 17   0.000163  HEOL   T4
# 388 -0.000179    T3  PO1
# 455  0.000217    T4  PO2
# ..        ...   ...  ...
# 398  0.282979    C3   T5
# 469 -0.335516   TP7  PO2
# 260 -0.371326    F4  PO2
# 293  0.386831   FT7  TP7
# 307 -0.513946   FT7  PO2
#
# [561 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7']
# -----Round: 7 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F4', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 122  0.000090  VEOL   F7
# 16   0.000163  HEOL   T4
# 355 -0.000179    T3  PO1
# 422  0.000217    T4  PO2
# 205 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 358  0.264908    C3   C4
# 237  0.270943    F4  TP7
# 365  0.282979    C3   T5
# 436 -0.335516   TP7  PO2
# 251 -0.371326    F4  PO2
#
# [528 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4']
# -----Round: 8 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'TP7', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 118  0.000090  VEOL   F7
# 15   0.000163  HEOL   T4
# 323 -0.000179    T3  PO1
# 390  0.000217    T4  PO2
# 197 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 195 -0.240648    F3  PO2
# 366  0.253286    C4   T5
# 326  0.264908    C3   C4
# 333  0.282979    C3   T5
# 404 -0.335516   TP7  PO2
#
# [496 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7']
# -----Round: 9 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'C3', 'CZ', 'C4', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 114  0.000090  VEOL   F7
# 15   0.000163  HEOL   T4
# 310 -0.000179    T3  PO1
# 373  0.000217    T4  PO2
# 190 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 293  0.204501   FT8  PO2
# 188 -0.240648    F3  PO2
# 350  0.253286    C4   T5
# 313  0.264908    C3   C4
# 319  0.282979    C3   T5
#
# [465 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3']
# -----Round: 10 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'CZ', 'C4', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 110  0.000090  VEOL   F7
# 14   0.000163  HEOL   T4
# 297 -0.000179    T3  PO1
# 343  0.000217    T4  PO2
# 183 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 274  0.163816   FT8   PZ
# 424 -0.192928    T6  PO2
# 281  0.204501   FT8  PO2
# 181 -0.240648    F3  PO2
# 320  0.253286    C4   T5
#
# [435 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4']
# -----Round: 11 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'F3', 'FZ', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 106  0.000090  VEOL    F7
# 13   0.000163  HEOL    T4
# 284 -0.000179    T3   PO1
# 314  0.000217    T4   PO2
# 176 -0.000259    FZ   FC3
# ..        ...   ...   ...
# 30   0.121417  HEOR  VEOL
# 262  0.163816   FT8    PZ
# 395 -0.192928    T6   PO2
# 269  0.204501   FT8   PO2
# 174 -0.240648    F3   PO2
#
# [406 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3']
# -----Round: 12 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'FT8', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 102  0.000090  VEOL    F7
# 12   0.000163  HEOL    T4
# 256 -0.000179    T3   PO1
# 286  0.000217    T4   PO2
# 148 -0.000259    FZ   FC3
# ..        ...   ...   ...
# 43   0.121043  HEOR    T5
# 29   0.121417  HEOR  VEOL
# 234  0.163816   FT8    PZ
# 367 -0.192928    T6   PO2
# 241  0.204501   FT8   PO2
#
# [378 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8']
# -----Round: 13 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'T6', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 98   0.000090  VEOL    F7
# 11   0.000163  HEOL    T4
# 229 -0.000179    T3   PO1
# 259  0.000217    T4   PO2
# 142 -0.000259    FZ   FC3
# ..        ...   ...   ...
# 119 -0.101233  VEOL   PO2
# 307  0.109747    T5    PZ
# 41   0.121043  HEOR    T5
# 28   0.121417  HEOR  VEOL
# 340 -0.192928    T6   PO2
#
# [351 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6']
# -----Round: 14 -----
# ['HEOL', 'HEOR', 'FP1', 'VEOU', 'VEOL', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1    C2
# 94   0.000090  VEOL    F7
# 11   0.000163  HEOL    T4
# 218 -0.000179    T3   PO1
# 246  0.000217    T4   PO2
# 136 -0.000259    FZ   FC3
# ..        ...   ...   ...
# 104  0.079141  VEOL   CP4
# 114 -0.101233  VEOL   PO2
# 290  0.109747    T5    PZ
# 40   0.121043  HEOR    T5
# 27   0.121417  HEOR  VEOL
#
# [325 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR']
# -----Round: 15 -----
# ['HEOL', 'FP1', 'VEOU', 'VEOL', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'T5', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 69   0.000090  VEOL   F7
# 10   0.000163  HEOL   T4
# 193 -0.000179    T3  PO1
# 221  0.000217    T4  PO2
# 111 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 83   0.071916  VEOL   PZ
# 93   0.073424    F7  FC4
# 79   0.079141  VEOL  CP4
# 89  -0.101233  VEOL  PO2
# 265  0.109747    T5   PZ
#
# [300 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5']
# -----Round: 16 -----
# ['HEOL', 'FP1', 'VEOU', 'VEOL', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 66   0.000090  VEOL   F7
# 10   0.000163  HEOL   T4
# 183 -0.000179    T3  PO1
# 209  0.000217    T4  PO2
# 106 -0.000259    FZ  FC3
# ..        ...   ...  ...
# 108  0.064489    FZ   T3
# 79   0.071916  VEOL   PZ
# 89   0.073424    F7  FC4
# 76   0.079141  VEOL  CP4
# 85  -0.101233  VEOL  PO2
#
# [276 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL']
# -----Round: 17 -----
# ['HEOL', 'FP1', 'VEOU', 'F7', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 9    0.000163  HEOL   T4
# 160 -0.000179    T3  PO1
# 186  0.000217    T4  PO2
# 83  -0.000259    FZ  FC3
# 73   0.000265    F7   A1
# ..        ...   ...  ...
# 67   0.046713    F7   T3
# 224 -0.052124    A1  PO2
# 56  -0.064245  VEOU   PZ
# 85   0.064489    FZ   T3
# 66   0.073424    F7  FC4
#
# [253 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7']
# -----Round: 18 -----
# ['HEOL', 'FP1', 'VEOU', 'FZ', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 8    0.000163  HEOL   T4
# 138 -0.000179    T3  PO1
# 164  0.000217    T4  PO2
# 61  -0.000259    FZ  FC3
# 171  0.000278   CP3   A2
# ..        ...   ...  ...
# 214 -0.045044    PZ  PO1
# 203  0.046086    P3   PZ
# 202 -0.052124    A1  PO2
# 53  -0.064245  VEOU   PZ
# 63   0.064489    FZ   T3
#
# [231 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ']
# -----Round: 19 -----
# ['HEOL', 'FP1', 'VEOU', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 7    0.000163  HEOL   T4
# 117 -0.000179    T3  PO1
# 143  0.000217    T4  PO2
# 150  0.000278   CP3   A2
# 121 -0.000363    CZ  CPZ
# ..        ...   ...  ...
# 144  0.044053   CP3  CPZ
# 193 -0.045044    PZ  PO1
# 182  0.046086    P3   PZ
# 181 -0.052124    A1  PO2
# 50  -0.064245  VEOU   PZ
#
# [210 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU']
# -----Round: 20 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'A1', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 6    0.000163  HEOL   T4
# 97  -0.000179    T3  PO1
# 123  0.000217    T4  PO2
# 130  0.000278   CP3   A2
# 101 -0.000363    CZ  CPZ
# ..        ...   ...  ...
# 168 -0.039137    P3  PO2
# 124  0.044053   CP3  CPZ
# 173 -0.045044    PZ  PO1
# 162  0.046086    P3   PZ
# 161 -0.052124    A1  PO2
#
# [190 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1']
# -----Round: 21 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'P3', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 6    0.000163  HEOL   T4
# 91  -0.000179    T3  PO1
# 115  0.000217    T4  PO2
# 121  0.000278   CP3   A2
# 95  -0.000363    CZ  CPZ
# ..        ...   ...  ...
# 158  0.038725    P4  FT9
# 149 -0.039137    P3  PO2
# 116  0.044053   CP3  CPZ
# 154 -0.045044    PZ  PO1
# 143  0.046086    P3   PZ
#
# [171 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3']
# -----Round: 22 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'PZ', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 6    0.000163  HEOL   T4
# 85  -0.000179    T3  PO1
# 107  0.000217    T4  PO2
# 112  0.000278   CP3   A2
# 89  -0.000363    CZ  CPZ
# ..        ...   ...  ...
# 124  0.034218   CPZ  PO2
# 142 -0.036443    P4  PO2
# 140  0.038725    P4  FT9
# 108  0.044053   CP3  CPZ
# 136 -0.045044    PZ  PO1
#
# [153 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ']
# -----Round: 23 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP3', 'CPZ', 'CP4', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 6    0.000163  HEOL   T4
# 79  -0.000179    T3  PO1
# 99   0.000217    T4  PO2
# 103  0.000278   CP3   A2
# 83  -0.000363    CZ  CPZ
# ..        ...   ...  ...
# 129 -0.028464    A2  PO2
# 114  0.034218   CPZ  PO2
# 125 -0.036443    P4  PO2
# 123  0.038725    P4  FT9
# 100  0.044053   CP3  CPZ
#
# [136 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3']
# -----Round: 24 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CPZ', 'CP4', 'P4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of         value    C1   C2
# 6    0.000163  HEOL   T4
# 73  -0.000179    T3  PO1
# 91   0.000217    T4  PO2
# 76  -0.000363    CZ  CPZ
# 68  -0.000424    T3  CP4
# ..        ...   ...  ...
# 60   0.026573   FC4   A2
# 113 -0.028464    A2  PO2
# 98   0.034218   CPZ  PO2
# 109 -0.036443    P4  PO2
# 107  0.038725    P4  FT9
#
# [120 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4']
# -----Round: 25 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CPZ', 'CP4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of        value    C1   C2
# 6   0.000163  HEOL   T4
# 67 -0.000179    T3  PO1
# 83  0.000217    T4  PO2
# 70 -0.000363    CZ  CPZ
# 63 -0.000424    T3  CP4
# ..       ...   ...  ...
# 93  0.021088   CP4  PO1
# 13  0.025701  HEOL  PO2
# 55  0.026573   FC4   A2
# 98 -0.028464    A2  PO2
# 89  0.034218   CPZ  PO2
#
# [105 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ']
# -----Round: 26 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP4', 'A2', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of        value    C1   C2
# 6   0.000163  HEOL   T4
# 61 -0.000179    T3  PO1
# 75  0.000217    T4  PO2
# 57 -0.000424    T3  CP4
# 72  0.000635    T4   OZ
# ..       ...   ...  ...
# 89  0.020936   FT9  PO2
# 79  0.021088   CP4  PO1
# 12  0.025701  HEOL  PO2
# 50  0.026573   FC4   A2
# 84 -0.028464    A2  PO2
#
# [91 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2']
# -----Round: 27 -----
# ['HEOL', 'FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP4', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of        value    C1   C2
# 6   0.000163  HEOL   T4
# 55 -0.000179    T3  PO1
# 67  0.000217    T4  PO2
# 52 -0.000424    T3  CP4
# 64  0.000635    T4   OZ
# ..       ...   ...  ...
# 74 -0.019728    OZ  PO2
# 32  0.019840    F8  PO2
# 76  0.020936   FT9  PO2
# 70  0.021088   CP4  PO1
# 11  0.025701  HEOL  PO2
#
# [78 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL']
# -----Round: 28 -----
# ['FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'CP4', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 43 -0.000179   T3  PO1
# 55  0.000217   T4  PO2
# 40 -0.000424   T3  CP4
# 52  0.000635   T4   OZ
# 13  0.000767   F8   T3
# ..       ...  ...  ...
# 57  0.016861  CP4  FT9
# 62 -0.019728   OZ  PO2
# 20  0.019840   F8  PO2
# 64  0.020936  FT9  PO2
# 58  0.021088  CP4  PO1
#
# [66 rows x 3 columns]>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4']
# -----Round: 29 -----
# ['FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'OZ', 'FT9', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 38 -0.000179   T3  PO1
# 48  0.000217   T4  PO2
# 45  0.000635   T4   OZ
# 12  0.000767   F8   T3
# 2   0.000942  FP1  FC4
# 5  -0.001065  FP1   T4
# 37 -0.001965   T3  FT9
# 14 -0.002205   F8   T4
# 40  0.002378   CZ   T4
# 34 -0.002577   T3   CZ
# 0   0.002866  FP1   F8
# 3   0.003146  FP1   T3
# 39 -0.003223   T3  PO2
# 30 -0.003252  FC4   OZ
# 35 -0.003303   T3   T4
# 42  0.003330   CZ  FT9
# 50  0.003395   OZ  PO1
# 15  0.003593   F8   OZ
# 7  -0.003631  FP1  FT9
# 1  -0.003638  FP1  FC3
# 25  0.003885  FC3  PO1
# 17  0.004060   F8  PO1
# 4  -0.004253  FP1   CZ
# 16  0.004262   F8  FT9
# 23 -0.004434  FC3   OZ
# 11 -0.004447   F8  FC4
# 29  0.004600  FC4   T4
# 19 -0.005352  FC3  FC4
# 9   0.005549  FP1  PO2
# 24 -0.006138  FC3  FT9
# 47 -0.006370   T4  PO1
# 26  0.006847  FC3  PO2
# 54 -0.007048  PO1  PO2
# 32  0.008304  FC4  PO1
# 52  0.009023  FT9  PO1
# 28 -0.009152  FC4   CZ
# 22 -0.009220  FC3   T4
# 13 -0.009332   F8   CZ
# 41 -0.009490   CZ   OZ
# 6   0.009794  FP1   OZ
# 27 -0.009904  FC4   T3
# 43  0.010256   CZ  PO1
# 8  -0.010638  FP1  PO1
# 49 -0.011722   OZ  FT9
# 10 -0.012039   F8  FC3
# 46 -0.012131   T4  FT9
# 21 -0.012444  FC3   CZ
# 31 -0.012709  FC4  FT9
# 20 -0.013327  FC3   T3
# 36 -0.013925   T3   OZ
# 33  0.015412  FC4  PO2
# 44  0.016773   CZ  PO2
# 51 -0.019728   OZ  PO2
# 18  0.019840   F8  PO2
# 53  0.020936  FT9  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9']
# -----Round: 30 -----
# ['FP1', 'F8', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'OZ', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 33 -0.000179   T3  PO1
# 41  0.000217   T4  PO2
# 39  0.000635   T4   OZ
# 11  0.000767   F8   T3
# 2   0.000942  FP1  FC4
# 5  -0.001065  FP1   T4
# 13 -0.002205   F8   T4
# 35  0.002378   CZ   T4
# 30 -0.002577   T3   CZ
# 0   0.002866  FP1   F8
# 3   0.003146  FP1   T3
# 34 -0.003223   T3  PO2
# 27 -0.003252  FC4   OZ
# 31 -0.003303   T3   T4
# 42  0.003395   OZ  PO1
# 14  0.003593   F8   OZ
# 1  -0.003638  FP1  FC3
# 22  0.003885  FC3  PO1
# 15  0.004060   F8  PO1
# 4  -0.004253  FP1   CZ
# 21 -0.004434  FC3   OZ
# 10 -0.004447   F8  FC4
# 26  0.004600  FC4   T4
# 17 -0.005352  FC3  FC4
# 8   0.005549  FP1  PO2
# 40 -0.006370   T4  PO1
# 23  0.006847  FC3  PO2
# 44 -0.007048  PO1  PO2
# 28  0.008304  FC4  PO1
# 25 -0.009152  FC4   CZ
# 20 -0.009220  FC3   T4
# 12 -0.009332   F8   CZ
# 36 -0.009490   CZ   OZ
# 6   0.009794  FP1   OZ
# 24 -0.009904  FC4   T3
# 37  0.010256   CZ  PO1
# 7  -0.010638  FP1  PO1
# 9  -0.012039   F8  FC3
# 19 -0.012444  FC3   CZ
# 18 -0.013327  FC3   T3
# 32 -0.013925   T3   OZ
# 29  0.015412  FC4  PO2
# 38  0.016773   CZ  PO2
# 43 -0.019728   OZ  PO2
# 16  0.019840   F8  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8']
# -----Round: 31 -----
# ['FP1', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'OZ', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 24 -0.000179   T3  PO1
# 32  0.000217   T4  PO2
# 30  0.000635   T4   OZ
# 1   0.000942  FP1  FC4
# 4  -0.001065  FP1   T4
# 26  0.002378   CZ   T4
# 21 -0.002577   T3   CZ
# 2   0.003146  FP1   T3
# 25 -0.003223   T3  PO2
# 18 -0.003252  FC4   OZ
# 22 -0.003303   T3   T4
# 33  0.003395   OZ  PO1
# 0  -0.003638  FP1  FC3
# 13  0.003885  FC3  PO1
# 3  -0.004253  FP1   CZ
# 12 -0.004434  FC3   OZ
# 17  0.004600  FC4   T4
# 8  -0.005352  FC3  FC4
# 7   0.005549  FP1  PO2
# 31 -0.006370   T4  PO1
# 14  0.006847  FC3  PO2
# 35 -0.007048  PO1  PO2
# 19  0.008304  FC4  PO1
# 16 -0.009152  FC4   CZ
# 11 -0.009220  FC3   T4
# 27 -0.009490   CZ   OZ
# 5   0.009794  FP1   OZ
# 15 -0.009904  FC4   T3
# 28  0.010256   CZ  PO1
# 6  -0.010638  FP1  PO1
# 10 -0.012444  FC3   CZ
# 9  -0.013327  FC3   T3
# 23 -0.013925   T3   OZ
# 20  0.015412  FC4  PO2
# 29  0.016773   CZ  PO2
# 34 -0.019728   OZ  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ']
# -----Round: 32 -----
# ['FP1', 'FC3', 'FC4', 'T3', 'CZ', 'T4', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 20 -0.000179   T3  PO1
# 26  0.000217   T4  PO2
# 1   0.000942  FP1  FC4
# 4  -0.001065  FP1   T4
# 22  0.002378   CZ   T4
# 18 -0.002577   T3   CZ
# 2   0.003146  FP1   T3
# 21 -0.003223   T3  PO2
# 19 -0.003303   T3   T4
# 0  -0.003638  FP1  FC3
# 11  0.003885  FC3  PO1
# 3  -0.004253  FP1   CZ
# 15  0.004600  FC4   T4
# 7  -0.005352  FC3  FC4
# 6   0.005549  FP1  PO2
# 25 -0.006370   T4  PO1
# 12  0.006847  FC3  PO2
# 27 -0.007048  PO1  PO2
# 16  0.008304  FC4  PO1
# 14 -0.009152  FC4   CZ
# 10 -0.009220  FC3   T4
# 13 -0.009904  FC4   T3
# 23  0.010256   CZ  PO1
# 5  -0.010638  FP1  PO1
# 9  -0.012444  FC3   CZ
# 8  -0.013327  FC3   T3
# 17  0.015412  FC4  PO2
# 24  0.016773   CZ  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ']
# -----Round: 33 -----
# ['FP1', 'FC3', 'FC4', 'T3', 'T4', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 16 -0.000179   T3  PO1
# 19  0.000217   T4  PO2
# 1   0.000942  FP1  FC4
# 3  -0.001065  FP1   T4
# 2   0.003146  FP1   T3
# 17 -0.003223   T3  PO2
# 15 -0.003303   T3   T4
# 0  -0.003638  FP1  FC3
# 9   0.003885  FC3  PO1
# 12  0.004600  FC4   T4
# 6  -0.005352  FC3  FC4
# 5   0.005549  FP1  PO2
# 18 -0.006370   T4  PO1
# 10  0.006847  FC3  PO2
# 20 -0.007048  PO1  PO2
# 13  0.008304  FC4  PO1
# 8  -0.009220  FC3   T4
# 11 -0.009904  FC4   T3
# 4  -0.010638  FP1  PO1
# 7  -0.013327  FC3   T3
# 14  0.015412  FC4  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4']
# -----Round: 34 -----
# ['FP1', 'FC3', 'T3', 'T4', 'PO1', 'PO2']
# <bound method DataFrame.info of        value   C1   C2
# 10 -0.000179   T3  PO1
# 13  0.000217   T4  PO2
# 2  -0.001065  FP1   T4
# 1   0.003146  FP1   T3
# 11 -0.003223   T3  PO2
# 9  -0.003303   T3   T4
# 0  -0.003638  FP1  FC3
# 7   0.003885  FC3  PO1
# 4   0.005549  FP1  PO2
# 12 -0.006370   T4  PO1
# 8   0.006847  FC3  PO2
# 14 -0.007048  PO1  PO2
# 6  -0.009220  FC3   T4
# 3  -0.010638  FP1  PO1
# 5  -0.013327  FC3   T3>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3']
# -----Round: 35 -----
# ['FP1', 'T3', 'T4', 'PO1', 'PO2']
# <bound method DataFrame.info of       value   C1   C2
# 5 -0.000179   T3  PO1
# 8  0.000217   T4  PO2
# 1 -0.001065  FP1   T4
# 0  0.003146  FP1   T3
# 6 -0.003223   T3  PO2
# 4 -0.003303   T3   T4
# 3  0.005549  FP1  PO2
# 7 -0.006370   T4  PO1
# 9 -0.007048  PO1  PO2
# 2 -0.010638  FP1  PO1>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1']
# -----Round: 36 -----
# ['T3', 'T4', 'PO1', 'PO2']
# <bound method DataFrame.info of       value   C1   C2
# 1 -0.000179   T3  PO1
# 4  0.000217   T4  PO2
# 2 -0.003223   T3  PO2
# 0 -0.003303   T3   T4
# 3 -0.006370   T4  PO1
# 5 -0.007048  PO1  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1']
# -----Round: 37 -----
# ['T3', 'T4', 'PO2']
# <bound method DataFrame.info of       value  C1   C2
# 2  0.000217  T4  PO2
# 1 -0.003223  T3  PO2
# 0 -0.003303  T3   T4>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3']
# -----Round: 38 -----
# ['T4', 'PO2']
# <bound method DataFrame.info of       value  C1   C2
# 0  0.000217  T4  PO2>
# True
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 39 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 40 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 41 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 42 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 43 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 44 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 45 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 46 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 47 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 48 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 49 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 50 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 51 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 52 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 53 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 54 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 55 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 56 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 57 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 58 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 59 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 60 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 61 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 62 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 63 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 64 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 65 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 66 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 67 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 68 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 69 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 70 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 71 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 72 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 73 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 74 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 75 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 76 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 77 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 78 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 79 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 80 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 81 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 82 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 83 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 84 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 85 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 86 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 87 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 88 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 89 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 90 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 91 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# ...
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2057 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2058 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2059 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2060 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2061 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2062 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2063 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2064 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2065 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2066 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2067 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2068 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2069 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2070 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2071 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2072 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2073 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2074 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2075 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2076 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2077 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2078 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2079 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2080 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2081 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2082 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2083 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2084 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2085 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2086 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2087 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2088 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2089 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2090 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2091 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2092 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2093 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2094 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2095 -----
# ['PO2']
# <bound method DataFrame.info of Empty DataFrame
# Columns: [value, C1, C2]
# Index: []>
# rm_list: ['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4']
# -----Round: 2096 -----
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-f9037a21fc7e> in <module>
#       6     print("-----Round:", n, "-----")
#       7
# ----> 8     corr = hello.corr()
#       9     corr_list = []
#      10     FEATURE_COLUMNS = corr.columns.tolist()
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in corr(self, method, min_periods)
#    8131
#    8132         if method == "pearson":
# -> 8133             correl = libalgos.nancorr(mat, minp=min_periods)
#    8134         elif method == "spearman":
#    8135             correl = libalgos.nancorr_spearman(mat, minp=min_periods)
#
# KeyboardInterrupt:

# %%
# Greedy algorithm to pick elimiate 
['TP8', 'FP2', 'FCZ', 'FT10', 'O2', 'O1', 'FT7', 'F4', 'TP7', 'C3', 'C4', 'F3', 'FT8', 'T6', 'HEOR', 'T5', 'VEOL', 'F7', 'FZ', 'VEOU', 'A1', 'P3', 'PZ', 'CP3', 'P4', 'CPZ', 'A2', 'HEOL', 'CP4', 'FT9', 'F8', 'OZ', 'CZ', 'FC4', 'FC3', 'FP1', 'PO1', 'T3', 'T4', 'PO2']

# %%
# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
# cmap = sns.color_palette("coolwarm", as_cmap=True)   # for getting colors clostest 1 and -1
# cmap = sns.color_palette("hls", 8) # for separting colorts
cmap = sns.diverging_palette(145, 300, s=60, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, center=0,
            vmin=-1, vmax=1,
            square=True, linewidths=.5, cbar_kws={"shrink": 0.5})
