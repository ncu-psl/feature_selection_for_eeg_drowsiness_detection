# %%
import pandas as pd 
import dataframe as df

import torch
from torch import nn, optim

# %%
df = pd.read_csv('data1.csv')

# %%
df.head()

len(df)
# Out:
# 14424064

# %%
df.at[0, 'group']
# Out:
# 1

# %%
ng = 0 # new group 
for i in range(0, len(df)):
    df.at[i, 'group'] = ng
    if (df.at[i, 'id'] == 1023):
        ng += 1
        print(df.at[i, 'group'], df.at[i, 'time'])
print("OK!")
# Out:
# 0 1023
# 1 2047
# 2 3071
# 3 4095
# 4 5119
# 5 6143
# 6 7167
# 7 8191
# 8 9215
# 9 10239
# 10 11263
# 11 12287
# 12 13311
# 13 14335
# 14 15359
# 15 16383
# 16 17407
# 17 18431
# 18 19455
# 19 20479
# 20 21503
# 21 22527
# 22 23551
# 23 24575
# 24 25599
# 25 26623
# 26 27647
# 27 28671
# 28 29695
# 29 30719
# 30 31743
# 31 32767
# 32 33791
# 33 34815
# 34 35839
# 35 36863
# 36 37887
# 37 38911
# 38 39935
# 39 40959
# 40 41983
# 41 43007
# 42 44031
# 43 45055
# 44 46079
# 45 47103
# 46 48127
# 47 49151
# 48 50175
# 49 51199
# 50 52223
# 51 53247
# 52 54271
# 53 55295
# 54 56319
# 55 57343
# 56 58367
# 57 59391
# 58 60415
# 59 61439
# 60 62463
# 61 63487
# 62 64511
# 63 65535
# 64 66559
# 65 67583
# 66 68607
# 67 69631
# 68 70655
# 69 71679
# 70 72703
# 71 73727
# 72 74751
# 73 75775
# 74 76799
# 75 77823
# 76 78847
# 77 79871
# 78 80895
# 79 81919
# 80 82943
# 81 83967
# 82 84991
# 83 86015
# 84 87039
# 85 88063
# 86 89087
# 87 90111
# 88 91135
# 89 92159
# 90 93183
# 91 94207
# ...

# %%
# for i in range(0, 10000):
#     print(df.at[i, 'group'])

# %%
df.to_csv("data2.csv", index=False)
print("OK!")
# Out:
# OK!
